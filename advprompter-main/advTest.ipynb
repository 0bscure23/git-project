# %%
# 这个配置能跑起来，跑下面的cell，对照检查

# 当前环境已安装库列表：
# +---------------------------+--------------+---------------------------------------------------------+
# |          Package          |   Version    |                         Location                        |
# +---------------------------+--------------+---------------------------------------------------------+
# |           Brotli          |    1.0.9     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         GitPython         |    3.1.44    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           Jinja2          |    3.1.6     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         MarkupSafe        |    3.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          PySocks          |    1.7.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           PyYAML          |    6.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          Pygments         |    2.19.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         Send2Trash        |    1.8.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         accelerate        |    1.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      aiohappyeyeballs     |    2.6.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          aiohttp          |   3.11.18    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         aiosignal         |    1.3.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      annotated-types      |    0.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |   antlr4-python3-runtime  |    4.9.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           anyio           |    4.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           anyio           |    4.9.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          appdirs          |    1.4.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        argon2-cffi        |    21.3.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |    argon2-cffi-bindings   |    21.2.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            ase            |    3.22.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         asttokens         |    3.0.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         async-lru         |    2.0.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           attrs           |    24.3.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           attrs           |    25.3.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           babel           |    2.16.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       beautifulsoup4      |    4.12.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           bleach          |    6.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          certifi          |  2025.4.26   | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            cffi           |    1.17.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          chardet          |    5.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     charset-normalizer    |    3.3.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     charset-normalizer    |    3.4.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           click           |    8.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        cloudpickle        |    3.1.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          colorama         |    0.4.6     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            comm           |    0.2.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         contourpy         |    1.3.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           cycler          |    0.12.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          datasets         |    3.6.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          debugpy          |    1.8.11    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         decorator         |    5.1.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         decorator         |    5.2.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         defusedxml        |    0.7.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            dill           |    0.3.8     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       docker-pycreds      |    0.4.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         executing         |    0.8.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         executing         |    2.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          fastapi          |   0.115.12   | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       fastjsonschema      |    2.20.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          filelock         |    3.18.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         fonttools         |    4.58.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         frozenlist        |    1.6.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           fschat          |    0.2.36    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           fsspec          |   2024.2.0   | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           gitdb           |    4.0.12    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            h11            |    0.14.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            h11            |    0.16.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          httpcore         |    1.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          httpcore         |    1.0.9     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           httpx           |    0.28.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      huggingface-hub      |    0.31.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         hydra-core        |    1.3.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |  hydra-submitit-launcher  |    1.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            idna           |     3.10     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            idna           |     3.7      | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     importlib_metadata    |    8.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         ipykernel         |    6.29.5    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          ipython          |    8.23.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          ipython          |    9.1.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |  ipython_pygments_lexers  |    1.1.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            jedi           |    0.19.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           json5           |    0.9.25    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         jsonschema        |    4.23.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# | jsonschema-specifications |   2023.7.1   | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       jupyter-events      |    0.12.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        jupyter-lsp        |    2.2.5     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       jupyter_client      |    8.6.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        jupyter_core       |    5.7.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       jupyter_server      |    2.15.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |  jupyter_server_terminals |    0.5.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         jupyterlab        |    4.3.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |    jupyterlab_pygments    |    0.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     jupyterlab_server     |    2.27.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         kiwisolver        |    1.4.8     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        latex2mathml       |    3.78.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |    lightning-utilities    |    0.14.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       markdown-it-py      |    3.0.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         markdown2         |    2.5.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         matplotlib        |    3.8.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     matplotlib-inline     |    0.1.6     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     matplotlib-inline     |    0.1.7     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           mdurl           |    0.1.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          mistune          |    3.1.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           mpmath          |    1.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         multidict         |    6.4.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        multiprocess       |   0.70.16    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          nbclient         |    0.10.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         nbconvert         |    7.16.6    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          nbformat         |    5.10.4    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        nest-asyncio       |    1.6.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          networkx         |    3.4.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            nh3            |    0.2.21    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          notebook         |    7.3.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       notebook_shim       |    0.2.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           numpy           |    1.26.4    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         omegaconf         |    2.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           orjson          |   3.10.18    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         overrides         |    7.4.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         packaging         |     24.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         packaging         |     25.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           pandas          |    2.2.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       pandocfilters       |    1.5.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           parso           |    0.8.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            peft           |    0.10.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           pillow          |    11.2.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            pip            |     25.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        platformdirs       |    4.3.7     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        prettytable        |    3.16.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     prometheus_client     |    0.21.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       prompt-toolkit      |    3.0.43    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       prompt_toolkit      |    3.0.51    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         propcache         |    0.3.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          protobuf         |    4.25.7    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           psutil          |    5.9.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           psutil          |    7.0.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         pure-eval         |    0.2.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         pure_eval         |    0.2.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          pyarrow          |    20.0.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       pyarrow-hotfix      |     0.7      | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         pycparser         |     2.21     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          pydantic         |    2.11.4    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       pydantic_core       |    2.33.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         pyparsing         |    3.2.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      python-dateutil      | 2.9.0.post0  | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     python-json-logger    |    3.2.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     pytorch-lightning     |    2.2.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       pytorch-ranger      |    0.1.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            pytz           |    2025.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          pywin32          |     308      | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          pywinpty         |    2.0.15    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           pyzmq           |    26.2.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        referencing        |    0.30.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           regex           |  2024.11.6   | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          requests         |    2.32.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     rfc3339-validator     |    0.1.4     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     rfc3986-validator     |    0.1.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            rich           |    14.0.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          rpds-py          |    0.22.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        safetensors        |    0.5.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           scipy           |    1.15.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       sentencepiece       |    0.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         sentry-sdk        |    2.28.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        setproctitle       |    1.3.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         setuptools        |    78.1.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         shortuuid         |    1.0.13    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            six            |    1.17.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           smmap           |    5.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          sniffio          |    1.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          sniffio          |    1.3.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         soupsieve         |     2.5      | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         stack-data        |    0.2.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         stack-data        |    0.6.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         starlette         |    0.46.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          submitit         |    1.5.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          svgwrite         |    1.4.3     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           sympy           |    1.13.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         tensordict        |    0.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         terminado         |    0.17.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          tiktoken         |    0.9.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          tinycss2         |    1.4.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         tokenizers        |    0.21.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           torch           | 2.6.0+cu126  | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      torch-optimizer      |    0.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         torchaudio        | 2.6.0+cu126  | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        torchmetrics       |    1.7.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          torchrl          |    0.7.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        torchvision        | 0.21.0+cu126 | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          tornado          |    6.4.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            tqdm           |    4.67.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         traitlets         |    5.14.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        transformers       |    4.51.3    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            trl            |    0.17.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     typing-inspection     |    0.4.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     typing_extensions     |    4.12.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |     typing_extensions     |    4.13.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           tzdata          |    2025.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          urllib3          |    2.3.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          urllib3          |    2.4.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          uvicorn          |    0.34.2    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           wandb           |    0.16.6    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          wavedrom         | 2.0.3.post3  | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          wcwidth          |    0.2.13    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          wcwidth          |    0.2.5     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |        webencodings       |    0.5.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |      websocket-client     |    1.8.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           wheel           |    0.45.1    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |       win-inet-pton       |    1.1.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           xxhash          |    3.5.0     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            yarl           |    1.20.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |            zipp           |    3.21.0    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# +---------------------------+--------------+---------------------------------------------------------+

# %%
# 导入必要的库（替换 pkg_resources 为 importlib.metadata）
import importlib.metadata
from prettytable import PrettyTable

# 解决中文显示问题（可选）
# import sys
# if sys.stdout.encoding != 'utf-8':
#     sys.stdout = open(sys.stdout.fileno(), mode='w', encoding='utf-8', buffering=1)

# 获取所有已安装的库
installed_packages = importlib.metadata.distributions()

# 创建表格用于展示
table = PrettyTable()
table.field_names = ["Package", "Version", "Location"]

# 遍历并填充表格
for package in installed_packages:
    table.add_row([
        package.metadata["Name"],
        package.metadata["Version"],
        str(package.locate_file(""))  # 获取安装路径
    ])

# 打印表格（按库名排序）
print("当前环境已安装库列表：")
print(table.get_string(sortby="Package"))
# Out:
# 当前环境已安装库列表：
# +---------------------------+--------------+---------------------------------------------------------+
# |          Package          |   Version    |                         Location                        |
# +---------------------------+--------------+---------------------------------------------------------+
# |           Brotli          |    1.0.9     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         GitPython         |    3.1.44    | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           Jinja2          |    3.1.6     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |         MarkupSafe        |    3.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |          PySocks          |    1.7.1     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# |           PyYAML          |    6.0.2     | C:\Users\asus\.conda\envs\advprompter\Lib\site-packages |
# ...

# %%
# 更改到 git clone 的项目文件夹位置
# 比如 %cd root\advprompter
# %cd C:\Users\asus\Desktop\大创\advprompter-main
# Out:
# C:\Users\asus\Desktop\大创\advprompter-main

# %%
import subprocess
import sys  # 导入 sys 模块获取系统编码

command = [
    "python", "main.py",
    "--config-name=train",
    "target_llm=local_pythia",
    "target_llm.llm_params.checkpoint=EleutherAI/pythia-1.4b",
    "target_llm.llm_params.model_name=EleutherAI/pythia-1.4b"
]

process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
stdout, stderr = process.communicate()

# 获取系统默认编码（Windows 通常为 'gbk'）
encoding = sys.getdefaultencoding() if sys.platform != 'win32' else 'gbk'

print("标准输出：")
print(stdout.decode(encoding, errors='replace'))  # 使用 errors='replace' 处理无法解码的字符

print("标准错误：")
print(stderr.decode(encoding, errors='replace'))
# Out:
# 标准输出：
# Starting run...
# Using parameters:
# prompter:
#   llm_params:
#     device: cuda:0
#     freeze: false
#     dtype: float32
#     model_name: tiny_llama
#     checkpoint: TinyLlama/TinyLlama-1.1B-step-50K-105b
#     lora_params:
#       warmstart: false
#       lora_checkpoint: null
#       lora_config:
#         r: 8
#         lora_alpha: 16
#         bias: none
#         target_modules:
#         - q_proj
#         - v_proj
#         - lm_head
#   allow_non_ascii: false
#   gen_params:
#     do_sample: true
#     temperature: 1.0
#     top_p: 0.9
#   prompt_manager:
#     prompt_template:
#     - key: system_message
#       msg: <s>
#     - key: hyper_instruct
#       msg: '{instruct}'
#     - key: suffix
#       msg: '{suffix}'
# target_llm:
#   llm_params:
#     device: cuda:0
#     freeze: true
#     dtype: float16
#     lora_params: null
#     model_name: EleutherAI/pythia-1.4b
#     checkpoint: EleutherAI/pythia-1.4b
#   allow_non_ascii: true
#   gen_params:
# ...
